# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#读取数据
df = pd.read_excel('da.xlsx')
df  # data frame
df.head()
print(df)
# Out:
#      GPA   pay  city
# 0   4.00  7750     1
# 1   2.91  6091     0
# 2   3.11  7114     1
# 3   2.10  4702     0
# 4   3.96  7053     1
# 5   2.78  5074     0
# 6   3.60  6985     1
# 7   4.10  4765     0
# 8   3.40  5265     1
# 9   3.00  4293     0
# 10  4.10  7000     1
# 11  2.91  3445     0

# %%
matrix = df.corr()
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(matrix, square=True)
plt.title('city')
# Out:
# Text(0.5, 1, 'city')

# %%
# 训练模型
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
#标准化处理 
from sklearn.preprocessing import StandardScaler

import numpy as np
# d=d.reshape(-1,1)
X = df[['GPA', 'pay']].values
y = df['city'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2003)
clf = KNeighborsClassifier(n_neighbors=2)
clf.fit(X_train, y_train)
# 入参
d=[[3.1,4000]]
# k1=clf.kneighbors(x1,return_distance=False)
print(clf.predict(d))
# Out:
# [0]
# /home/jht/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':

# %%
from sklearn.metrics import accuracy_score
correct = np.count_nonzero((clf.predict(X_test)==y_test)==True)
#accuracy_score(y_test, clf.predict(X_test))
print ("Accuracy is: %.3f" %(correct/len(X_test)))
# Out:
# Accuracy is: 1.667

# %%
plt.figure(figsize =(16,14),dpi=144)
a=np.arange(0,5,0.01)
plt.scatter(X[:,0],X[:,1],)
plt.plot(a,1000*a)
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
plt.figure(figsize=(16, 8))
plt.scatter(df['GPA'], df['pay'], c ='black')
plt.xlabel("GPA values")
plt.ylabel("valus of pay")
plt.show()

# %%
X = df['GPA'].values.reshape(-1,1)
y = df['pay'].values.reshape(-1,1)

reg = LinearRegression()
reg.fit(X, y)
